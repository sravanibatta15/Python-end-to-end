# %% [markdown]
# **Pandas**
#
# - `Pandas it the only Python Library which is used for Data Manipulation `
# - `Pandas will only work with Exsheet data `
#
# There are Many Built_in_Functions in Pandas
#
# - `Series `
# - `DataFrame`
# - `shape `
# - `size`
# - `loc `
# - `iloc `
# - `unique `
# - `values_count`
# - `mean | median | mode | var | std `
# - `read_csv `
# - `head `
# - `tail `
# - `sample `
# - `drop `
# - `rename `
# - `axis = 1`
# - `axis = 0 `
# - `concat `
# - `get_dummies `
# - `groupBy `
# - `select_dtypes `
# - `to_numeric `
# - `fillna `
# - `dropna `
# - `to_csv`

# %%
import pandas as pd

# %%
# Series Function in pandas library is used for only [1D data]

a = pd.Series([10,20,50,90,30])

a
# Out:
# 0    10
# 1    20
# 2    50
# 3    90
# 4    30
# dtype: int64

# %%
a[2]
# Out:
# np.int64(50)

# %%
# DataFrame

a = {'Name' : ['john','peter','steve','brad','smith','hasan'] ,
     'Age' : [20,30,40,22,23,32] ,
     'Location': ['usa','uk','paris','india','canada','dubai'] ,
     'company': ['google','meta','msft','IBM','infosys','atai'],
     'salary':[1200,1400,1900,1100,1000,2100],
     'role':['manager','ML','DL','TL','Fresher','HR']
     }

b = pd.DataFrame(a , index = ['r1','r2','r3','r4','r5','r6'])

b
# Out:
#      Name  Age Location  company  salary     role
# r1   john   20      usa   google    1200  manager
# r2  peter   30       uk     meta    1400       ML
# r3  steve   40    paris     msft    1900       DL
# r4   brad   22    india      IBM    1100       TL
# r5  smith   23   canada  infosys    1000  Fresher
# r6  hasan   32    dubai     atai    2100       HR

# %%
b['salary']['r5']
# Out:
# np.int64(1000)

# %%
a['Location'][2]
# Out:
# 'paris'

# %%
b['Name']['r4']
# Out:
# 'brad'

# %%
b
# Out:
#      Name  Age Location  company  salary     role
# r1   john   20      usa   google    1200  manager
# r2  peter   30       uk     meta    1400       ML
# r3  steve   40    paris     msft    1900       DL
# r4   brad   22    india      IBM    1100       TL
# r5  smith   23   canada  infosys    1000  Fresher
# r6  hasan   32    dubai     atai    2100       HR

# %%
b.iloc[2:5 , 3:]
# Out:
#     company  salary     role
# r3     msft    1900       DL
# r4      IBM    1100       TL
# r5  infosys    1000  Fresher

# %%
b.loc['r4':'r5' , 'Name':'salary']
# Out:
#      Name  Age Location  company  salary
# r4   brad   22    india      IBM    1100
# r5  smith   23   canada  infosys    1000

# %%
b.iloc[3:5 , 0:5]
# Out:
#      Name  Age Location  company  salary
# r4   brad   22    india      IBM    1100
# r5  smith   23   canada  infosys    1000

# %%
b.loc['r2':'r4' , 'Age':'salary']
# Out:
#     Age Location company  salary
# r2   30       uk    meta    1400
# r3   40    paris    msft    1900
# r4   22    india     IBM    1100

# %%
b.iloc[1:4 , 1:5]
# Out:
#     Age Location company  salary
# r2   30       uk    meta    1400
# r3   40    paris    msft    1900
# r4   22    india     IBM    1100

# %%
b
# Out:
#      Name  Age Location  company  salary     role
# r1   john   20      usa   google    1200  manager
# r2  peter   30       uk     meta    1400       ML
# r3  steve   40    paris     msft    1900       DL
# r4   brad   22    india      IBM    1100       TL
# r5  smith   23   canada  infosys    1000  Fresher
# r6  hasan   32    dubai     atai    2100       HR

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
b['Location']['r3'] = 'italy'

# %%
b
# Out:
#      Name  Age Location  company  salary     role
# r1   john   20      usa   google    1200  manager
# r2  peter   30       uk     meta    1400       ML
# r3  steve   40    italy     msft    1900       DL
# r4   brad   22    india      IBM    1100       TL
# r5  smith   23   canada  infosys    1000  Fresher
# r6  hasan   32    dubai     atai    2100       HR

# %%
# axis = 1 -> column
# axis = 0 -> row

# %%
b = b.drop(['salary'],axis=1)

# %%
b
# Out:
#      Name  Age Location  company     role
# r1   john   20      usa   google  manager
# r2  peter   30       uk     meta       ML
# r3  steve   40    italy     msft       DL
# r4   brad   22    india      IBM       TL
# r5  smith   23   canada  infosys  Fresher
# r6  hasan   32    dubai     atai       HR

# %%
b = b.drop(['r4'],axis=0)

# %%
b
# Out:
#      Name  Age Location  company     role
# r1   john   20      usa   google  manager
# r2  peter   30       uk     meta       ML
# r3  steve   40    italy     msft       DL
# r5  smith   23   canada  infosys  Fresher
# r6  hasan   32    dubai     atai       HR

# %%
b.shape # (r , c)
# Out:
# (5, 5)

# %%
b.size
# Out:
# 25

# %%
b
# Out:
#      Name  Age Location  company     role
# r1   john   20      usa   google  manager
# r2  peter   30       uk     meta       ML
# r3  steve   40    italy     msft       DL
# r5  smith   23   canada  infosys  Fresher
# r6  hasan   32    dubai     atai       HR

# %%
b = b.rename(columns={'Location' : 'Area'})

# %%
b
# Out:
#      Name  Age    Area  company     role
# r1   john   20     usa   google  manager
# r2  peter   30      uk     meta       ML
# r3  steve   40   italy     msft       DL
# r5  smith   23  canada  infosys  Fresher
# r6  hasan   32   dubai     atai       HR

# %%
b['Age'] = [1,2,3,4,5]

# %%
b
# Out:
#      Name  Age    Area  company     role
# r1   john    1     usa   google  manager
# r2  peter    2      uk     meta       ML
# r3  steve    3   italy     msft       DL
# r5  smith    4  canada  infosys  Fresher
# r6  hasan    5   dubai     atai       HR

# %%
b['EMI'] = [10,20,30,40,50]

# %%
b
# Out:
#      Name  Age    Area  company     role  EMI
# r1   john    1     usa   google  manager   10
# r2  peter    2      uk     meta       ML   20
# r3  steve    3   italy     msft       DL   30
# r5  smith    4  canada  infosys  Fresher   40
# r6  hasan    5   dubai     atai       HR   50

# %%
import numpy as np

# %%
b['TAX_Ratio'] = [100,np.nan,200,np.nan,400]

# %%
b
# Out:
#      Name  Age    Area  company     role  EMI  TAX_Ratio
# r1   john    1     usa   google  manager   10      100.0
# r2  peter    2      uk     meta       ML   20        NaN
# r3  steve    3   italy     msft       DL   30      200.0
# r5  smith    4  canada  infosys  Fresher   40        NaN
# r6  hasan    5   dubai     atai       HR   50      400.0

# %%
b.to_csv('Employess_detailed_data.csv',index=False)

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 30            31         0       1     Uruchurtu, Don. Manuel E  male  40.0
# 778          779         0       3      Kilgannon, Mr. Thomas J  male   NaN
# 370          371         1       1  Harder, Mr. George Achilles  male  25.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 30       0      0  PC 17601  27.7208   NaN        C
# 778      0      0     36865   7.7375   NaN        Q
# 370      1      0     11765  55.4417   E50        C

# %%
# info = which gives complete information about data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(['PassengerId','Name','Ticket'],axis = 1)

# %%
df.sample(4)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 852         0       3  female   9.0      1      1  15.2458   NaN        C
# 34          0       1    male  28.0      1      0  82.1708   NaN        C
# 72          0       2    male  21.0      0      0  73.5000   NaN        S

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 458         1       2  female  50.0      0      0   10.5000   NaN        S
# 69          0       3    male  26.0      2      0    8.6625   NaN        S
# 550         1       1    male  17.0      0      2  110.8833   C70        C
# 494         0       3    male  21.0      0      0    8.0500   NaN        S
# 369         1       1  female  24.0      0      0   69.3000   B35        C
# 244         0       3    male  30.0      0      0    7.2250   NaN        C
# 230         1       1  female  35.0      1      0   83.4750   C83        S

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
577 + 314
# Out:
# 891

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 552         0       3    male   NaN      0      0   7.8292   NaN        Q
# 447         1       1    male  34.0      0      0  26.5500   NaN        S
# 336         0       1    male  29.0      1      0  66.6000    C2        S
# 709         1       3    male   NaN      1      1  15.2458   NaN        C
# 122         0       2    male  32.5      1      0  30.0708   NaN        C
# 653         1       3  female   NaN      0      0   7.8292   NaN        Q
# 167         0       3  female  45.0      1      4  27.9000   NaN        S

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df['Fare'].median()
# Out:
# 14.4542

# %%
df['Fare'].mode()
# Out:
# 0    8.05
# Name: Fare, dtype: float64

# %%
df['Fare'].var()
# Out:
# 2469.436845743117

# %%
df['Fare'].std()
# Out:
# 49.693428597180905

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 773         0       3    male   NaN      0      0   7.2250   NaN        C
# 11          1       1  female  58.0      0      0  26.5500  C103        S
# 555         0       1    male  62.0      0      0  26.5500   NaN        S
# 567         0       3  female  29.0      0      4  21.0750   NaN        S
# 854         0       2  female  44.0      1      0  26.0000   NaN        S
# 369         1       1  female  24.0      0      0  69.3000   B35        C
# 36          1       3    male   NaN      0      0   7.2292   NaN        C

# %%
df['Age'] = df['Age'].fillna(10)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.sample(10)
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 245         0       1  male  44.0      2      0  90.0000   C78        Q
# 675         0       3  male  18.0      0      0   7.7750   NaN        S
# 828         1       3  male  10.0      0      0   7.7500   NaN        Q
# 170         0       1  male  61.0      0      0  33.5000   B19        S
# 876         0       3  male  20.0      0      0   9.8458   NaN        S
# 723         0       2  male  50.0      0      0  13.0000   NaN        S
# 739         0       3  male  10.0      0      0   7.8958   NaN        S
# 672         0       2  male  70.0      0      0  10.5000   NaN        S
# 646         0       3  male  19.0      0      0   7.8958   NaN        S
# 637         0       2  male  31.0      1      1  26.2500   NaN        S

# %%
df = df.dropna()

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 124         0       1    male  54.0      0      1  77.2875   D26        S
# 776         0       3    male  10.0      0      0   7.7500   F38        Q
# 632         1       1    male  32.0      0      0  30.5000   B50        C
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 327         1       2  female  36.0      0      0  13.0000     D        S
# 671         0       1    male  31.0      1      0  52.0000   B71        S
# 185         0       1    male  10.0      0      0  50.0000   A32        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 202 entries, 1 to 889
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  202 non-null    int64
#  1   Pclass    202 non-null    int64
#  2   Sex       202 non-null    object
#  3   Age       202 non-null    float64
#  4   SibSp     202 non-null    int64
#  5   Parch     202 non-null    int64
#  6   Fare      202 non-null    float64
#  7   Cabin     202 non-null    object
#  8   Embarked  202 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.8+ KB

# %%
text_column_data = df.select_dtypes(include = 'object')

# %%
text_column_data.sample(5)
# Out:
#         Sex Cabin Embarked
# 496  female   D20        C
# 284    male   A19        S
# 632    male   B50        C
# 62     male   C83        S
# 759  female   B77        S

# %%
num_column_data = df.select_dtypes(exclude='object')

# %%
num_column_data.sample(7)
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare
# 183         1       2   1.0      2      1   39.0000
# 715         0       3  19.0      0      0    7.6500
# 1           1       1  38.0      1      0   71.2833
# 591         1       1  52.0      1      0   78.2667
# 435         1       1  14.0      1      2  120.0000
# 309         1       1  30.0      0      0   56.9292
# 31          1       1  10.0      1      0  146.5208

# %%
# titanic data = df
# sample_data = b

# %%
b
# Out:
#      Name  Age    Area  company     role  EMI  TAX_Ratio
# r1   john    1     usa   google  manager   10      100.0
# r2  peter    2      uk     meta       ML   20        NaN
# r3  steve    3   italy     msft       DL   30      200.0
# r5  smith    4  canada  infosys  Fresher   40        NaN
# r6  hasan    5   dubai     atai       HR   50      400.0

# %%
b['pincode'] = ['12','15','18','20','22']

# %%
b
# Out:
#      Name  Age    Area  company     role  EMI  TAX_Ratio pincode
# r1   john    1     usa   google  manager   10      100.0      12
# r2  peter    2      uk     meta       ML   20        NaN      15
# r3  steve    3   italy     msft       DL   30      200.0      18
# r5  smith    4  canada  infosys  Fresher   40        NaN      20
# r6  hasan    5   dubai     atai       HR   50      400.0      22

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, r1 to r6
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   Area       5 non-null      object
#  3   company    5 non-null      object
#  4   role       5 non-null      object
#  5   EMI        5 non-null      int64
#  6   TAX_Ratio  3 non-null      float64
#  7   pincode    5 non-null      object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 532.0+ bytes

# %%
b['pincode'] = pd.to_numeric(b['pincode'])

# %%
b
# Out:
#      Name  Age    Area  company     role  EMI  TAX_Ratio  pincode
# r1   john    1     usa   google  manager   10      100.0       12
# r2  peter    2      uk     meta       ML   20        NaN       15
# r3  steve    3   italy     msft       DL   30      200.0       18
# r5  smith    4  canada  infosys  Fresher   40        NaN       20
# r6  hasan    5   dubai     atai       HR   50      400.0       22

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, r1 to r6
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int64
#  2   Area       5 non-null      object
#  3   company    5 non-null      object
#  4   role       5 non-null      object
#  5   EMI        5 non-null      int64
#  6   TAX_Ratio  3 non-null      float64
#  7   pincode    5 non-null      int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 532.0+ bytes

# %%
f = {'Gender':['M','F','M','F','M']}
t = pd.DataFrame(f)
t
# Out:
#   Gender
# 0      M
# 1      F
# 2      M
# 3      F
# 4      M

# %%
b.reset_index(drop=True,inplace=True)

# %%
b
# Out:
#     Name  Age    Area  company     role  EMI  TAX_Ratio  pincode
# 0   john    1     usa   google  manager   10      100.0       12
# 1  peter    2      uk     meta       ML   20        NaN       15
# 2  steve    3   italy     msft       DL   30      200.0       18
# 3  smith    4  canada  infosys  Fresher   40        NaN       20
# 4  hasan    5   dubai     atai       HR   50      400.0       22

# %%
p = pd.concat([b , t],axis=1)

# %%
p
# Out:
#     Name  Age    Area  company     role  EMI  TAX_Ratio  pincode Gender
# 0   john    1     usa   google  manager   10      100.0       12      M
# 1  peter    2      uk     meta       ML   20        NaN       15      F
# 2  steve    3   italy     msft       DL   30      200.0       18      M
# 3  smith    4  canada  infosys  Fresher   40        NaN       20      F
# 4  hasan    5   dubai     atai       HR   50      400.0       22      M

# %%
p['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
p['Gender'].value_counts()
# Out:
# Gender
# M    3
# F    2
# Name: count, dtype: int64

# %%
# get dummies

p['Gender'] = p['Gender'].map({'M':0,'F':1}).astype(int)

# %%
p
# Out:
#     Name  Age    Area  company     role  EMI  TAX_Ratio  pincode  Gender
# 0   john    1     usa   google  manager   10      100.0       12       0
# 1  peter    2      uk     meta       ML   20        NaN       15       1
# 2  steve    3   italy     msft       DL   30      200.0       18       0
# 3  smith    4  canada  infosys  Fresher   40        NaN       20       1
# 4  hasan    5   dubai     atai       HR   50      400.0       22       0

# %%
# groupBY

f = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

f
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
f.groupby(['Animal']).sum()
# Out:
#         Max Speed
# Animal
# Falcon      750.0
# Parrot       50.0

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare        Cabin  \
# 1           1       1  female  38.0      1      0  71.2833          C85
# 3           1       1  female  35.0      1      0  53.1000         C123
# 6           0       1    male  54.0      0      0  51.8625          E46
# 10          1       3  female   4.0      1      1  16.7000           G6
# 11          1       1  female  58.0      0      0  26.5500         C103
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 871         1       1  female  47.0      1      1  52.5542          D35
# 872         0       1    male  33.0      0      0   5.0000  B51 B53 B55
# 879         1       1  female  56.0      0      1  83.1583          C50
# 887         1       1  female  19.0      0      0  30.0000          B42
# 889         1       1    male  26.0      0      0  30.0000         C148
#
#     Embarked
# 1          C
# 3          S
# 6          S
# 10         S
# 11         S
# ..       ...
# ...

# %%
df.to_csv('cleaned_titanic.csv',index=False)
