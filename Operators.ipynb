# %%
# +,-,*,/,//,%,**,pow,>,<,>=,<=,!=,=,==,and,or

# %%
10 + 20
# Out:
# 30

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
10 - 20
# Out:
# -10

# %%
20 * 5
# Out:
# 100

# %%
22 / 5
# Out:
# 4.4

# %%
22 // 5
# Out:
# 4

# %%
22 % 5
# Out:
# 2

# %%
38 / 6
# Out:
# 6.333333333333333

# %%
38 // 6
# Out:
# 6

# %%
38 % 6
# Out:
# 2

# %%
2 ** 5
# Out:
# 32

# %%
10 > 20
# Out:
# False

# %%
21 < 40
# Out:
# True

# %%
10 != 9
# Out:
# True

# %%
a = 20
print(a)
# Out:
# 20

# %%
10 == 10
# Out:
# True

# %%
10 >= 5
# Out:
# True

# %%
25 >= 15
# Out:
# True

# %%
10 > 5 or 10 < 4
# Out:
# True

# %%
25 <= 15 or 50 >= 9
# Out:
# True

# %%
10 > 9 and 25 < 19
# Out:
# False

# %%
10 > 9 and 25 > 19
# Out:
# True

# %%
import math  # opening math library

# %%
len(dir(math))
# Out:
# 65

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import scipy.stats

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,5)
# Out:
# 2

# %%
pow(5,6,7,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-3457603121.py in <cell line: 0>()
# ----> 1 pow(5,6,7,9)
#
# TypeError: pow() takes at most 3 arguments (4 given)
